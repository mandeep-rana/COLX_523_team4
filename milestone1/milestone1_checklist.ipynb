# %% [markdown]
# # COLX 523 - Advanced Corpus Linguistics
#
# # Milestone 1 checklist
#
# ## Repo setup
# rubric={mechanics:2}
#
# - [x] All team members have write access, and the instructors (Julian, Jungyeul) have read access
# - [x] Message instructors on slack with the path to the repo
# - [x] Create a branch for each member
# - [ ] One folder for each milestone in the main repo directory where stores milestone-specific written documents
# - [ ] Have a readme with information about where to find any required code
# - [ ] Make sure all required things are in the master branch before the deadline
#
# ## Team work contract
# rubric={reasoning:2, writing:2}
#
# - [x] All team members agree to the contract
# - [x] The document contains no spelling/grammar errors
#
# ## Project proposal
# rubric={reasoning:5,writing:2}
#
# - [x] Describe the corpus intended to build
# - [x] Includes the following:
#     - [x] Source of the data: link to the website
#     - [x] The kind of text
#     - [x] Language it is in
#     - [x] Genre/register
#     - [x] What are the text about
#     - [x] Who wrote the text
#     - [x] How long are the documents generally
#     - [x] Will you be targeting a specific kind of text among those available on the site?
#         - [x] If so, how will you be filtering the texts to just the kind you want?
#         - [x] Is there enough data there to create a "Brown-sized" corpus?
#     - [x] Is there any structure to the corpus you are building (e.g. discussion threads)?
#     - [x] Any metadata (e.g. related to author identity)?
#     - [x] What annotation (can be tentative)
#     - [x] What format to store the corpus and associated metadata
#     - [x] What makes this corpus potentially of interest
#     - [x] What could the corpus be used for
#
# ## Corpus collection POC (proof-of-concept)
# rubric={accuracy:2,reasoning:2,writing:1}
#
# - [x] Have Pyhon code that downloads one document
#     - [x] Make sure the code is runnable
#     - [ ] Provide explicit explanation on how to use it, assuming someone has cloned your repo
#     - [x] Can be either .ipynb or .py
# - [x] Have a step-by-step algorithm for creating the corpus
#     - [x] Include links to the website or API documentation for functions used
#     - [ ] Write as clearly as possible
#
# ## Prompt completion
# rubric={raw:4}
#
# - [ ] Finish the above by deadline: 11:59pm Saturday, Feb 27th
# - [ ] One team member opens an issue in the repo to indicate completion of a milestone
#     - [ ] DO NOT modify anything after issue is opened, can lead to loss of ALL completion points
#
# ## Compelling proposal (Optional)
# rubric={raw:2}
#
# You can get bonus points in this milestone by having a particularly compelling proposal, one which, for instance, has the potential to answer research questions, service an under-resourced language or group, or otherwise be applied usefully beyond this course (training data for an important task, for instance). Projects done in languages other than English, using less obvious sources of data, and involving synergy between annotation and metadata are more likely to get these bonus points. Discussing similar corpora that are available might be useful to convince us that your corpus is going to be something special.
